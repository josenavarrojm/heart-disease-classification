# %%
# Heart Disease Dataset - Exploratory Data Analysis
# Author: Jose Navarro Meneses

# 📦 Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 📐 Set visual style
sns.set(style="whitegrid")
# %matplotlib inline

# 📁 Load dataset
df = pd.read_csv("../data/heart.csv")
print("✅ Dataset loaded with shape:", df.shape)

# 🔍 First 5 rows
df.head()
# Out:
# ✅ Dataset loaded with shape: (918, 12)
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
# 📊 1. Target Variable Distribution

sns.countplot(x="HeartDisease", data=df, palette="Set2")
plt.title("Distribution of Target Variable (HeartDisease)")
plt.xlabel("HeartDisease (0 = No, 1 = Yes)")
plt.ylabel("Count")
plt.show()
# Out:
# C:\Users\Junior\AppData\Local\Temp\ipykernel_6732\4082995556.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="HeartDisease", data=df, palette="Set2")

# %%
# 📈 2. Basic statistics

df.describe(include="all").T
# Out:
#                 count unique     top freq        mean         std   min  \
# Age             918.0    NaN     NaN  NaN   53.510893    9.432617  28.0
# Sex               918      2       M  725         NaN         NaN   NaN
# ChestPainType     918      4     ASY  496         NaN         NaN   NaN
# RestingBP       918.0    NaN     NaN  NaN  132.396514   18.514154   0.0
# Cholesterol     918.0    NaN     NaN  NaN  198.799564  109.384145   0.0
# FastingBS       918.0    NaN     NaN  NaN    0.233115    0.423046   0.0
# RestingECG        918      3  Normal  552         NaN         NaN   NaN
# MaxHR           918.0    NaN     NaN  NaN  136.809368   25.460334  60.0
# ExerciseAngina    918      2       N  547         NaN         NaN   NaN
# Oldpeak         918.0    NaN     NaN  NaN    0.887364     1.06657  -2.6
# ST_Slope          918      3    Flat  460         NaN         NaN   NaN
# HeartDisease    918.0    NaN     NaN  NaN    0.553377    0.497414   0.0
#
# ...

# %%
# 🧠 3. Distribution of key numerical features by class

num_cols = ["Age", "RestingBP", "Cholesterol", "MaxHR", "Oldpeak"]

for col in num_cols:
    plt.figure(figsize=(7, 4))
    sns.histplot(data=df, x=col, hue="HeartDisease", kde=True, bins=30, palette="Set1")
    plt.title(f"{col} Distribution by HeartDisease")
    plt.show()

# %%
# 📦 4. Boxplots by target

for col in num_cols:
    plt.figure(figsize=(6, 4))
    sns.boxplot(x="HeartDisease", y=col, data=df, palette="Set2")
    plt.title(f"{col} vs HeartDisease")
    plt.show()
# Out:
# C:\Users\Junior\AppData\Local\Temp\ipykernel_6732\1884185745.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="HeartDisease", y=col, data=df, palette="Set2")
# C:\Users\Junior\AppData\Local\Temp\ipykernel_6732\1884185745.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="HeartDisease", y=col, data=df, palette="Set2")
# C:\Users\Junior\AppData\Local\Temp\ipykernel_6732\1884185745.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="HeartDisease", y=col, data=df, palette="Set2")
# ...

# %%
# 🧮 5. Categorical feature analysis

cat_cols = ["Sex", "ChestPainType", "RestingECG", "ExerciseAngina", "ST_Slope"]

for col in cat_cols:
    plt.figure(figsize=(6, 4))
    sns.countplot(x=col, hue="HeartDisease", data=df, palette="Set3")
    plt.title(f"{col} by HeartDisease")
    plt.xticks(rotation=30)
    plt.show()

# %%
# 🔥 6. Correlation heatmap

plt.figure(figsize=(12, 10))
corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
# ✅ 7. Observations & Hypotheses

from IPython.display import Markdown

Markdown("""
### ✅ Observations

- Age and Cholesterol distributions are skewed higher for patients with heart disease.
- Chest pain type seems highly predictive.
- `Oldpeak` and `ST_Slope` are clearly correlated with the presence of disease.
- RestingBP is not strongly correlated with disease in this dataset.

### 💡 Hypotheses

- Patients with `ST_Slope = Flat` are more likely to have heart disease.
- `ExerciseAngina` and `ChestPainType` will be strong predictors.
- `Oldpeak` might be linearly related to heart disease probability.

These hypotheses will be tested during model training.
""")
# Out:
# ### ✅ Observations
#
# - Age and Cholesterol distributions are skewed higher for patients with heart disease.
# - Chest pain type seems highly predictive.
# - `Oldpeak` and `ST_Slope` are clearly correlated with the presence of disease.
# - RestingBP is not strongly correlated with disease in this dataset.
#
# ### 💡 Hypotheses
#
# - Patients with `ST_Slope = Flat` are more likely to have heart disease.
# - `ExerciseAngina` and `ChestPainType` will be strong predictors.
# - `Oldpeak` might be linearly related to heart disease probability.
#
# These hypotheses will be tested during model training.
